# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#plt.scatter(df['sepal_length'], df['sepal_width'], c=df['species'])
sns.lmplot(x='sepal_length', y='sepal_width', data=df, hue='species', fit_reg=False)
sns.lmplot(x='petal_length', y='petal_width', data=df, hue='species', fit_reg=False)

# %%
df_x = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
df_y = df[['species']]

# %%
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(df_x)

# %%
nbrs
# Out:
# NearestNeighbors(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=2, p=2, radius=1.0)

# %%
distances, indices = nbrs.kneighbors([[5.5,2,4,1.5]])

# %%
indices, distances
# Out:
# (array([[53, 89]]), array([[0.36055513, 0.53851648]]))

# %%
one = indices[0][0]

# %%
two = indices[0,1]

# %%
df.iloc[one,:]
# Out:
# sepal_length           5.5
# sepal_width            2.3
# petal_length             4
# petal_width            1.3
# species         versicolor
# Name: 53, dtype: object

# %%
df.iloc[two,:]
# Out:
# sepal_length           5.5
# sepal_width            2.5
# petal_length             4
# petal_width            1.3
# species         versicolor
# Name: 89, dtype: object
