# %%
import tensorflow as tf
import pymysql as db
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import NearestNeighbors

# %%
conn = db.connect(host='192.168.2.88', port=3306, user='zach', passwd='1qaz!QAZ', db='old')

# %%
cursor = conn.cursor()

# %%
query_visits = 'SELECT * from old.matomo_log_visit;'

# %%
df_ = pd.read_sql_query(query_visits, conn)

# %%
pd.options.display.max_columns = len(df_.columns)
pd.options.display.max_rows = len(df_.columns)

# %%
df = df_[['idvisit', 'idsite', 'idvisitor', 'user_id', 'visitor_count_visits',
       'visit_total_actions', 'visitor_days_since_last', 'visit_total_time']]

# %%
df = df.groupby(['idvisitor', 'idsite']).agg({'idvisitor': 'count',
                                         'visit_total_actions': 'mean',
                                         'visit_total_time': 'mean',
                                         'visitor_days_since_last': 'mean'}).unstack()

# %%
df = df.rename(columns={'idvisitor' : 'visit_counts'})

# %%
df
# Out:
#                                     visit_counts                           \
# idsite                                         1      4     5     6     7
# idvisitor
# b'\x02\x8d\xde\x8b\xde\xb9\x02\x80'          1.0    NaN   NaN   NaN   NaN
# b'\x05$v\xa2\xd1&\x16\x0f'                  16.0    NaN   NaN   NaN   NaN
# b'\x07\xc2\x83_\xfa\x05\xd64'                1.0    NaN   NaN   NaN   NaN
# b'\x07\xdc\xd3qV\x0b\xc4<'                   NaN    NaN   6.0   NaN   NaN
# b'\x08\x14\x9f\xb5N\x1dL2'                   3.0    NaN   NaN   NaN   NaN
# b'\x08\xbc\xe2\xd9\xa3 k\xf0'                NaN    NaN  25.0   NaN   NaN
# b'\n\xb7\xd0w\xc2\x85\xf2\xa1'              26.0    NaN   NaN   NaN   NaN
# b"\n\xfa\x91^\x8bK'I"                        4.0    NaN   NaN   NaN   NaN
# b'\x11p\xcc\xb8\xc5\xe4\x8f~'                NaN  127.0   NaN   NaN   NaN
# b'\x156\xb6\xb8X\xbcz\xc5'                   4.0    NaN   NaN   NaN   NaN
# ...

# %%
#flatten multiindex and assign new column names to df
mi = df.columns
mi.tolist()
ind = pd.Index([e[0] + str(e[1]) for e in mi.tolist()])
df.columns = ind

# %%
df.columns
# Out:
# Index(['visit_counts1', 'visit_counts4', 'visit_counts5', 'visit_counts6',
#        'visit_counts7', 'visit_counts8', 'visit_total_actions1',
#        'visit_total_actions4', 'visit_total_actions5', 'visit_total_actions6',
#        'visit_total_actions7', 'visit_total_actions8', 'visit_total_time1',
#        'visit_total_time4', 'visit_total_time5', 'visit_total_time6',
#        'visit_total_time7', 'visit_total_time8', 'visitor_days_since_last1',
#        'visitor_days_since_last4', 'visitor_days_since_last5',
#        'visitor_days_since_last6', 'visitor_days_since_last7',
#        'visitor_days_since_last8'],
#       dtype='object')

# %%
df[['visit_counts1', 'visit_counts4', 'visit_counts5', 'visit_counts6',
       'visit_counts7', 'visit_counts8', 'visit_total_actions1',
       'visit_total_actions4', 'visit_total_actions5', 'visit_total_actions6',
       'visit_total_actions7', 'visit_total_actions8', 'visit_total_time1',
       'visit_total_time4', 'visit_total_time5', 'visit_total_time6',
       'visit_total_time7', 'visit_total_time8']] = df[['visit_counts1', 'visit_counts4', 'visit_counts5', 'visit_counts6',
       'visit_counts7', 'visit_counts8', 'visit_total_actions1',
       'visit_total_actions4', 'visit_total_actions5', 'visit_total_actions6',
       'visit_total_actions7', 'visit_total_actions8', 'visit_total_time1',
       'visit_total_time4', 'visit_total_time5', 'visit_total_time6',
       'visit_total_time7', 'visit_total_time8']].fillna(value=0)

# %%
df[['visitor_days_since_last1',
       'visitor_days_since_last4', 'visitor_days_since_last5',
       'visitor_days_since_last6', 'visitor_days_since_last7',
       'visitor_days_since_last8']] = df[['visitor_days_since_last1',
       'visitor_days_since_last4', 'visitor_days_since_last5',
       'visitor_days_since_last6', 'visitor_days_since_last7',
       'visitor_days_since_last8']].fillna(value=999999)

# %%
df
# Out:
#                                      visit_counts1  visit_counts4  \
# idvisitor
# b'\x02\x8d\xde\x8b\xde\xb9\x02\x80'            1.0            0.0
# b'\x05$v\xa2\xd1&\x16\x0f'                    16.0            0.0
# b'\x07\xc2\x83_\xfa\x05\xd64'                  1.0            0.0
# b'\x07\xdc\xd3qV\x0b\xc4<'                     0.0            0.0
# b'\x08\x14\x9f\xb5N\x1dL2'                     3.0            0.0
# b'\x08\xbc\xe2\xd9\xa3 k\xf0'                  0.0            0.0
# b'\n\xb7\xd0w\xc2\x85\xf2\xa1'                26.0            0.0
# b"\n\xfa\x91^\x8bK'I"                          4.0            0.0
# b'\x11p\xcc\xb8\xc5\xe4\x8f~'                  0.0          127.0
# b'\x156\xb6\xb8X\xbcz\xc5'                     4.0            0.0
# b'\x16\xc6G\xfd\xf7\xacr\xa4'                  1.0            0.0
# b'\x18\x87\x9cLb\xd4\xd3\x84'                  3.0            0.0
# b'\x19\xcc\x87\x7f\xc0\x18\xe9I'               9.0            0.0
# ...

# %%
#need 2 n_neighbors, otherwise the algorithms just finds itself. select second result as closest neighbor
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(df)

# %%
nbrs
# Out:
# NearestNeighbors(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=2, p=2, radius=1.0)

# %%
user1 = df.loc[b'\x05$v\xa2\xd1&\x16\x0f', :]

# %%
user1
# Out:
# visit_counts1                   16.000
# visit_counts4                    0.000
# visit_counts5                    0.000
# visit_counts6                    0.000
# visit_counts7                    0.000
# visit_counts8                    0.000
# visit_total_actions1             5.500
# visit_total_actions4             0.000
# visit_total_actions5             0.000
# visit_total_actions6             0.000
# visit_total_actions7             0.000
# visit_total_actions8             0.000
# visit_total_time1              727.625
# visit_total_time4                0.000
# visit_total_time5                0.000
# visit_total_time6                0.000
# visit_total_time7                0.000
# visit_total_time8                0.000
# visitor_days_since_last1         0.000
# visitor_days_since_last4    999999.000
# visitor_days_since_last5    999999.000
# visitor_days_since_last6    999999.000
# visitor_days_since_last7    999999.000
# visitor_days_since_last8    999999.000
# ...

# %%
# numbers are for each column
distances, indices = nbrs.kneighbors([user1])

# %%
indices, distances
# Out:
# (array([[ 1, 48]]), array([[  0.        ,  16.78215198]]))

# %%
user_high = df.loc[b'\xa9J\x8f\xe5\xcc\xb1\x9b\xa6', :]

# %%
user_high
# Out:
# visit_counts1                    0.000000
# visit_counts4                   31.000000
# visit_counts5                  228.000000
# visit_counts6                    0.000000
# visit_counts7                    9.000000
# visit_counts8                    9.000000
# visit_total_actions1             0.000000
# visit_total_actions4            24.000000
# visit_total_actions5             8.399123
# visit_total_actions6             0.000000
# visit_total_actions7             1.333333
# visit_total_actions8             1.777778
# visit_total_time1                0.000000
# visit_total_time4              245.612903
# visit_total_time5              115.820175
# visit_total_time6                0.000000
# visit_total_time7               84.333333
# visit_total_time8               88.000000
# visitor_days_since_last1    999999.000000
# visitor_days_since_last4         0.451613
# visitor_days_since_last5         0.061404
# visitor_days_since_last6    999999.000000
# ...

# %%
distances, indices = nbrs.kneighbors([user1])

# %%
distances, indices
# Out:
# (array([[ 0.]]), array([[0]]))
